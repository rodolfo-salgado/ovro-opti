# %% [markdown]
# # Optimization of regions for OVRO scheduler
#
# **Walter Max-Moerbeck, Aug 26, 2023**
#
# **Antonia Bravo Rojo, Jan 10, 2024**

# %%
import pandas 
import random
import time
#import ipynb.fs.full.region_optimizer as regopt 
import ipynb.fs.full.region_optimizer_with_genetic as regopt 

import importlib
importlib.reload(regopt)
# Out:
# <module 'ipynb.fs.full.region_optimizer_with_genetic' (/Users/antoniabravo/Desktop/region_optimization_py3/region_optimizer_with_genetic.ipynb)>

# %%
# Load the catalog
catalog = pandas.read_csv('fermi_20230821_a_summary.txt', sep='\t')

# Converto to source format of scheduler
sources = {}
for ii in range(catalog.shape[0]):
    sources[catalog.iloc[ii]['name']] = dict(catalog.iloc[ii, 1:4])

# Converto to region format of scheduler
regions = []

list_regions = catalog.region_number.unique()
list_regions.sort()

for ii in list_regions:

    # Extract sources for region ii and sort with the pointing calibartor first
    sources_in_region = catalog.loc[catalog['region_number'] == ii]
    sources_in_region = sources_in_region.sort_values(by='pointing', ascending=False)

    # Shuffle the sources because they are already optimizaed in the file
    if len(sources_in_region) > 1:
        order_part = list(range(1, len(sources_in_region['name'])))
        random.shuffle(order_part)
        order = [0] + order_part
    else:
        order = range(len(sources_in_region['name']))
        
    
    regions.append({'number': ii,
                    'sources': sources_in_region['name'].values.tolist(),
                    'order': order,
                    'ra': sources_in_region.iloc[0]['ra'],
                    'dec': sources_in_region.iloc[0]['dec']})

# %% [markdown]
# ### Run for results with genetic algorithm (GA)

# %% [markdown]
# **Antonia Bravo, Oct 09, 2023**

# %%
last_order = []
cant=0
for k in range(143):
    if k in [23,43,78,100,120]: #para las regiones vacias
        element = [k, []]
        cant+=1
    else:
        if cant!=0:
            element = [int(regions[k-cant]['number']), regions[k-cant]['order']]
        else:
            element = [int(regions[k]['number']), regions[k]['order']]
    last_order.append(element)

# %%
t0 = time.time()
sources, regions, data = regopt.optimize_all_regions(sources, regions, last_order, n_exact=10)
tf = time.time()
time_taken = tf-t0
print('Total program execution time is:', time_taken/60, 'minutes.')
# Out:
# ---------------------------------------
# Optimizing region  0 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.3778446765065404
# Final length =  0.8893404240009084
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.5963925233155961
# optimum travel order =   [0, 4, 3, 5, 1, 2, 6, 9, 7, 8, 11, 10]
#
#
# ---------------------------------------
# Optimizing region  1 n_sources =  24
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.9346445031731134
# Final length =  0.8284335188163654
# time spent on source for a given region =  0.5762777777777779
# slewing time percentage =  0.3043765556454767
# optimum travel order =   [0, 14, 13, 8, 12, 6, 21, 20, 16, 15, 1, 7, 9, 19, 2, 17, 3, 23, 18, 5, 22, 4, 11, 10]
#
#
# ---------------------------------------
# Optimizing region  2 n_sources =  15
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.8885605724257122
# Final length =  0.9684185230605884
# time spent on source for a given region =  0.41327777777777797
# slewing time percentage =  0.5732446582375815
# optimum travel order =   [0, 7, 9, 12, 4, 10, 3, 1, 2, 6, 8, 11, 14, 13, 5]
#
#
# ---------------------------------------
# Optimizing region  3 n_sources =  15
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  3.18728796036196
# Final length =  0.6390860976544346
# time spent on source for a given region =  0.41327777777777797
# slewing time percentage =  0.3533300453654294
# optimum travel order =   [0, 5, 2, 8, 10, 1, 11, 14, 12, 9, 4, 13, 7, 3, 6]
#
#
# ---------------------------------------
# Optimizing region  4 n_sources =  7
# Exact solution
# Initial path obstime =  0.421772165475911
# Final path length =  0.3490583515118182
# slewing time percentage =  0.23110595198063336
# ---------------------------------------
# Optimizing region  5 n_sources =  13
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.3752928878556459
# Final length =  0.5271834270563658
# time spent on source for a given region =  0.3770555555555557
# slewing time percentage =  0.28477350348260966
# optimum travel order =   [0, 12, 10, 1, 8, 9, 7, 5, 4, 11, 3, 6, 2]
#
#
# ---------------------------------------
# Optimizing region  6 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5505698341968586
# Final length =  0.46574280156135917
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.22930758512827917
# optimum travel order =   [0, 10, 11, 9, 8, 1, 6, 2, 7, 5, 4, 3]
#
#
# ---------------------------------------
# Optimizing region  7 n_sources =  23
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.9097376582374768
# Final length =  0.8172396634625674
# time spent on source for a given region =  0.5581666666666668
# slewing time percentage =  0.3170098177788297
# optimum travel order =   [0, 19, 5, 9, 7, 20, 17, 18, 16, 11, 4, 21, 6, 8, 1, 10, 14, 15, 12, 22, 3, 2, 13]
#
#
# ---------------------------------------
# Optimizing region  8 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.8130472432448759
# Final length =  0.884353209045134
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.5941164222923905
# optimum travel order =   [0, 4, 2, 7, 6, 1, 5, 8, 11, 10, 9, 3]
#
#
# ---------------------------------------
# Optimizing region  9 n_sources =  9
# Exact solution
# Initial path obstime =  0.4578533194859631
# Final path length =  0.3853278799008599
# slewing time percentage =  0.20947554796843712
# ---------------------------------------
# Optimizing region  10 n_sources =  22
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  2.5559467487943657
# Final length =  0.841311347571601
# time spent on source for a given region =  0.5400555555555557
# slewing time percentage =  0.3580788407117098
# optimum travel order =   [0, 9, 17, 7, 5, 20, 10, 8, 14, 12, 16, 18, 2, 1, 21, 15, 4, 19, 3, 11, 13, 6]
#
#
# ---------------------------------------
# Optimizing region  11 n_sources =  4
# Exact solution
# Initial path obstime =  0.266868099898808
# Final path length =  0.25180011781899836
# slewing time percentage =  0.14989890628476504
# ---------------------------------------
# Optimizing region  12 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7092628071802167
# Final length =  0.5092735223796296
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.29518337657288357
# optimum travel order =   [0, 1, 3, 2, 6, 5, 4, 11, 10, 9, 8, 7]
#
#
# ---------------------------------------
# Optimizing region  13 n_sources =  6
# Exact solution
# Initial path obstime =  0.3759428360992778
# Final path length =  0.31592838485247343
# slewing time percentage =  0.2078021799318602
# ---------------------------------------
# Optimizing region  14 n_sources =  6
# Exact solution
# Initial path obstime =  0.31831388690758367
# Final path length =  0.3147010623103883
# slewing time percentage =  0.20471263763663475
# ---------------------------------------
# Optimizing region  15 n_sources =  21
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  2.6545150393585226
# Final length =  0.8446174138745297
# time spent on source for a given region =  0.5219444444444447
# slewing time percentage =  0.38203447398731827
# optimum travel order =   [0, 9, 4, 6, 7, 14, 15, 1, 5, 3, 10, 12, 13, 20, 17, 19, 2, 18, 11, 16, 8]
#
#
# ---------------------------------------
# Optimizing region  16 n_sources =  23
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.0578070675551272
# Final length =  0.8373734089603184
# time spent on source for a given region =  0.5581666666666668
# slewing time percentage =  0.3334315841726026
# optimum travel order =   [0, 19, 4, 15, 9, 7, 10, 1, 8, 11, 13, 6, 22, 14, 18, 20, 3, 21, 16, 5, 17, 12, 2]
#
#
# ---------------------------------------
# Optimizing region  17 n_sources =  26
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.0822429292541837
# Final length =  0.9160932407980784
# time spent on source for a given region =  0.6125
# slewing time percentage =  0.33139993537513196
# optimum travel order =   [0, 8, 25, 17, 6, 16, 24, 19, 3, 14, 12, 15, 5, 4, 10, 7, 21, 23, 1, 22, 20, 18, 11, 13, 2, 9]
#
#
# ---------------------------------------
# Optimizing region  18 n_sources =  29
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  2.5898285082716317
# Final length =  1.6015999603854745
# time spent on source for a given region =  0.6668333333333333
# slewing time percentage =  0.583645510847266
# optimum travel order =   [0, 13, 25, 24, 1, 11, 28, 27, 8, 21, 17, 2, 10, 23, 22, 18, 26, 14, 16, 19, 15, 12, 5, 3, 4, 9, 6, 20, 7]
#
#
# ---------------------------------------
# Optimizing region  19 n_sources =  23
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.0017096774477352
# Final length =  0.8326124056378781
# time spent on source for a given region =  0.5581666666666668
# slewing time percentage =  0.32962004542912604
# optimum travel order =   [0, 12, 1, 10, 22, 20, 21, 19, 5, 7, 4, 14, 9, 3, 2, 6, 17, 15, 16, 18, 8, 13, 11]
#
#
# ---------------------------------------
# Optimizing region  20 n_sources =  29
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.3395969697774568
# Final length =  1.069472661738482
# time spent on source for a given region =  0.6668333333333333
# slewing time percentage =  0.37648398393899857
# optimum travel order =   [0, 1, 11, 17, 16, 13, 21, 15, 2, 4, 27, 24, 25, 5, 9, 10, 19, 26, 3, 18, 7, 12, 14, 20, 6, 8, 22, 23, 28]
#
#
# ---------------------------------------
# Optimizing region  21 n_sources =  19
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.8205742321725182
# Final length =  0.6899440106956689
# time spent on source for a given region =  0.4857222222222225
# slewing time percentage =  0.29599762489064885
# optimum travel order =   [0, 7, 8, 1, 5, 9, 10, 6, 11, 12, 13, 14, 2, 18, 3, 4, 17, 16, 15]
#
#
# ---------------------------------------
# Optimizing region  22 n_sources =  5
# Exact solution
# Initial path obstime =  0.28138100834470237
# Final path length =  0.2687168257992383
# slewing time percentage =  0.13601738195537755
# ---------------------------------------
# Optimizing region  24 n_sources =  14
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6103922873181098
# Final length =  0.5502342422402862
# time spent on source for a given region =  0.39516666666666683
# slewing time percentage =  0.2818210203390098
# optimum travel order =   [0, 12, 13, 11, 2, 3, 4, 5, 1, 7, 6, 8, 9, 10]
#
#
# ---------------------------------------
# Optimizing region  25 n_sources =  21
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.0468003910699613
# Final length =  0.7952852023117174
# time spent on source for a given region =  0.5219444444444447
# slewing time percentage =  0.3437015514342929
# optimum travel order =   [0, 8, 17, 5, 6, 7, 11, 14, 13, 12, 10, 1, 20, 3, 2, 18, 4, 19, 15, 9, 16]
#
#
# ---------------------------------------
# Optimizing region  26 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6134305413178547
# Final length =  0.5037756139573164
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.28749142574642966
# optimum travel order =   [0, 1, 2, 4, 8, 7, 6, 5, 9, 3, 10, 11]
#
#
# ---------------------------------------
# Optimizing region  27 n_sources =  5
# Exact solution
# Initial path obstime =  0.3167659951815933
# Final path length =  0.28776114114578766
# slewing time percentage =  0.19319660138182224
# ---------------------------------------
# Optimizing region  28 n_sources =  19
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.2328412893749956
# Final length =  0.8230880290086233
# time spent on source for a given region =  0.4857222222222225
# slewing time percentage =  0.40987815992506227
# optimum travel order =   [0, 2, 5, 15, 14, 18, 12, 17, 16, 10, 13, 1, 9, 4, 11, 3, 7, 6, 8]
#
#
# ---------------------------------------
# Optimizing region  29 n_sources =  23
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  2.0244865554149545
# Final length =  0.9758785137527228
# time spent on source for a given region =  0.5581666666666668
# slewing time percentage =  0.4280367291618634
# optimum travel order =   [0, 4, 21, 12, 14, 19, 11, 22, 13, 20, 17, 16, 15, 18, 10, 7, 9, 5, 1, 2, 3, 6, 8]
#
#
# ---------------------------------------
# Optimizing region  30 n_sources =  27
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.3055796832398627
# Final length =  1.0082922597234258
# time spent on source for a given region =  0.6306111111111111
# slewing time percentage =  0.37457507480610086
# optimum travel order =   [0, 26, 25, 24, 2, 22, 3, 18, 1, 17, 12, 10, 9, 21, 20, 11, 13, 16, 14, 4, 5, 6, 8, 15, 23, 7, 19]
#
#
# ---------------------------------------
# Optimizing region  31 n_sources =  18
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.9068918148532958
# Final length =  0.7271526105207062
# time spent on source for a given region =  0.46761111111111137
# slewing time percentage =  0.3569285121918767
# optimum travel order =   [0, 17, 15, 1, 16, 14, 2, 11, 12, 3, 4, 5, 6, 7, 8, 10, 9, 13]
#
#
# ---------------------------------------
# Optimizing region  32 n_sources =  18
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7981640219955164
# Final length =  0.6665740851778015
# time spent on source for a given region =  0.46761111111111137
# slewing time percentage =  0.2984859125053127
# optimum travel order =   [0, 16, 1, 14, 15, 11, 7, 5, 4, 2, 6, 8, 13, 17, 3, 9, 10, 12]
#
#
# ---------------------------------------
# Optimizing region  33 n_sources =  23
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.2895644109244486
# Final length =  0.9058262717342682
# time spent on source for a given region =  0.5581666666666668
# slewing time percentage =  0.38380384397770073
# optimum travel order =   [0, 22, 9, 12, 16, 21, 20, 5, 6, 3, 4, 7, 2, 8, 13, 15, 14, 17, 19, 10, 1, 11, 18]
#
#
# ---------------------------------------
# Optimizing region  34 n_sources =  14
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.2403573437908726
# Final length =  0.677320058053164
# time spent on source for a given region =  0.39516666666666683
# slewing time percentage =  0.41657321089456123
# optimum travel order =   [0, 3, 5, 6, 4, 2, 1, 7, 10, 12, 11, 13, 8, 9]
#
#
# ---------------------------------------
# Optimizing region  35 n_sources =  26
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.2116676356310982
# Final length =  0.9906256073282798
# time spent on source for a given region =  0.6125
# slewing time percentage =  0.38170384909399385
# optimum travel order =   [0, 19, 23, 13, 1, 9, 8, 6, 7, 16, 5, 4, 17, 10, 12, 11, 15, 25, 3, 2, 14, 22, 21, 24, 18, 20]
#
#
# ---------------------------------------
# Optimizing region  36 n_sources =  14
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.684739435815441
# Final length =  0.5412761939463202
# time spent on source for a given region =  0.39516666666666683
# slewing time percentage =  0.2699352547068483
# optimum travel order =   [0, 3, 1, 2, 7, 11, 9, 4, 5, 8, 6, 10, 12, 13]
#
#
# ---------------------------------------
# Optimizing region  37 n_sources =  10
# Exact solution
# Initial path obstime =  0.48632660440322084
# Final path length =  0.42172889302188565
# slewing time percentage =  0.23476378412262447
# ---------------------------------------
# Optimizing region  38 n_sources =  6
# Exact solution
# Initial path obstime =  0.3642488803277537
# Final path length =  0.35273009956627277
# slewing time percentage =  0.2904552855411925
# ---------------------------------------
# Optimizing region  39 n_sources =  18
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7733146981034693
# Final length =  0.6645843676290539
# time spent on source for a given region =  0.46761111111111137
# slewing time percentage =  0.29638563004522195
# optimum travel order =   [0, 9, 1, 3, 4, 2, 17, 16, 14, 5, 15, 11, 12, 13, 10, 6, 7, 8]
#
#
# ---------------------------------------
# Optimizing region  40 n_sources =  24
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.0501374073058294
# Final length =  0.9049071616586737
# time spent on source for a given region =  0.5762777777777779
# slewing time percentage =  0.3631636457363491
# optimum travel order =   [0, 19, 17, 14, 16, 9, 5, 6, 12, 18, 23, 21, 22, 1, 10, 8, 7, 11, 13, 3, 4, 2, 20, 15]
#
#
# ---------------------------------------
# Optimizing region  41 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.572870121655382
# Final length =  0.4842234962504097
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.25872154650913254
# optimum travel order =   [0, 1, 3, 4, 2, 5, 7, 9, 8, 10, 11, 6]
#
#
# ---------------------------------------
# Optimizing region  42 n_sources =  15
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6342405232320205
# Final length =  0.547560910635827
# time spent on source for a given region =  0.41327777777777797
# slewing time percentage =  0.24523871271621572
# optimum travel order =   [0, 8, 7, 10, 9, 6, 2, 4, 1, 3, 5, 14, 13, 12, 11]
#
#
# ---------------------------------------
# Optimizing region  44 n_sources =  20
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.052925507026548
# Final length =  0.7883229040243673
# time spent on source for a given region =  0.5038333333333336
# slewing time percentage =  0.36087949397223157
# optimum travel order =   [0, 3, 9, 19, 4, 7, 5, 6, 1, 11, 13, 16, 18, 17, 15, 12, 14, 10, 8, 2]
#
#
# ---------------------------------------
# Optimizing region  45 n_sources =  19
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.9295405472963711
# Final length =  0.7485606267470128
# time spent on source for a given region =  0.4857222222222225
# slewing time percentage =  0.35112507275061433
# optimum travel order =   [0, 13, 3, 12, 7, 1, 5, 9, 11, 4, 6, 8, 2, 10, 15, 14, 16, 18, 17]
#
#
# ---------------------------------------
# Optimizing region  46 n_sources =  22
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.9566845942212225
# Final length =  0.8313740538169139
# time spent on source for a given region =  0.5400555555555557
# slewing time percentage =  0.35040604998903735
# optimum travel order =   [0, 18, 17, 1, 19, 16, 6, 21, 5, 13, 15, 10, 9, 20, 8, 4, 14, 2, 7, 12, 3, 11]
#
#
# ---------------------------------------
# Optimizing region  47 n_sources =  15
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.71294144477422
# Final length =  0.5661145838676731
# time spent on source for a given region =  0.41327777777777797
# slewing time percentage =  0.2699750376429449
# optimum travel order =   [0, 2, 4, 3, 5, 1, 7, 10, 9, 8, 14, 13, 12, 11, 6]
#
#
# ---------------------------------------
# Optimizing region  48 n_sources =  17
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.754018354898994
# Final length =  0.6467925631915783
# time spent on source for a given region =  0.44950000000000023
# slewing time percentage =  0.30503220726293434
# optimum travel order =   [0, 3, 11, 10, 8, 12, 1, 9, 13, 14, 16, 2, 15, 7, 5, 6, 4]
#
#
# ---------------------------------------
# Optimizing region  49 n_sources =  17
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.8485528422438104
# Final length =  0.6650028562215748
# time spent on source for a given region =  0.44950000000000023
# slewing time percentage =  0.32406305357246523
# optimum travel order =   [0, 14, 15, 10, 8, 5, 6, 7, 16, 2, 3, 4, 1, 13, 9, 11, 12]
#
#
# ---------------------------------------
# Optimizing region  50 n_sources =  16
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7085185972719596
# Final length =  0.6269895821096156
# time spent on source for a given region =  0.4313888888888891
# slewing time percentage =  0.31196801159373966
# optimum travel order =   [0, 2, 1, 7, 10, 12, 15, 6, 9, 11, 13, 14, 8, 5, 4, 3]
#
#
# ---------------------------------------
# Optimizing region  51 n_sources =  25
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.1778577571105089
# Final length =  0.9532044804335413
# time spent on source for a given region =  0.594388888888889
# slewing time percentage =  0.37643086967179806
# optimum travel order =   [0, 19, 17, 15, 11, 1, 3, 13, 22, 5, 9, 4, 6, 7, 8, 21, 16, 20, 18, 12, 14, 23, 2, 24, 10]
#
#
# ---------------------------------------
# Optimizing region  52 n_sources =  7
# Exact solution
# Initial path obstime =  0.349061866360703
# Final path length =  0.32681477911517476
# slewing time percentage =  0.17877370902402073
# ---------------------------------------
# Optimizing region  53 n_sources =  7
# Exact solution
# Initial path obstime =  0.42779517785822563
# Final path length =  0.35733511781540983
# slewing time percentage =  0.2489154423732522
# ---------------------------------------
# Optimizing region  54 n_sources =  15
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.728529746101227
# Final length =  0.5841952794844332
# time spent on source for a given region =  0.41327777777777797
# slewing time percentage =  0.2925691249294143
# optimum travel order =   [0, 7, 9, 8, 5, 10, 4, 11, 6, 2, 1, 3, 14, 12, 13]
#
#
# ---------------------------------------
# Optimizing region  55 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5404352672936525
# Final length =  0.49265146193316056
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.2714028635255657
# optimum travel order =   [0, 3, 2, 5, 4, 1, 11, 10, 9, 8, 7, 6]
#
#
# ---------------------------------------
# Optimizing region  56 n_sources =  24
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  1.0553264578175856
# Final length =  0.8629569195946623
# time spent on source for a given region =  0.5762777777777779
# slewing time percentage =  0.33220562383524294
# optimum travel order =   [0, 23, 20, 19, 22, 2, 21, 17, 15, 14, 6, 8, 9, 12, 13, 18, 3, 1, 16, 4, 5, 11, 10, 7]
#
#
# ---------------------------------------
# Optimizing region  57 n_sources =  16
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6765281206902655
# Final length =  0.5915946177741667
# time spent on source for a given region =  0.4313888888888891
# slewing time percentage =  0.2708032224634504
# optimum travel order =   [0, 9, 3, 7, 4, 5, 6, 2, 10, 8, 1, 11, 12, 13, 14, 15]
#
#
# ---------------------------------------
# Optimizing region  58 n_sources =  8
# Exact solution
# Initial path obstime =  0.40098184342624443
# Final path length =  0.35571548577463785
# slewing time percentage =  0.19458103046570488
# ---------------------------------------
# Optimizing region  59 n_sources =  10
# Exact solution
# Initial path obstime =  0.4493109832977682
# Final path length =  0.39770167362287623
# slewing time percentage =  0.18853189808739348
# ---------------------------------------
# Optimizing region  60 n_sources =  6
# Exact solution
# Initial path obstime =  0.30917226924913166
# Final path length =  0.3045611734713294
# slewing time percentage =  0.17823478638081133
# ---------------------------------------
# Optimizing region  61 n_sources =  11
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5744581642495827
# Final length =  0.468022121604756
# time spent on source for a given region =  0.34083333333333343
# slewing time percentage =  0.27175806954448467
# optimum travel order =   [0, 1, 2, 4, 3, 5, 6, 7, 10, 9, 8]
#
#
# ---------------------------------------
# Optimizing region  62 n_sources =  14
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6486145587810004
# Final length =  0.5454017918733864
# time spent on source for a given region =  0.39516666666666683
# slewing time percentage =  0.2754577037429248
# optimum travel order =   [0, 8, 4, 3, 1, 2, 5, 6, 7, 10, 9, 13, 12, 11]
#
#
# ---------------------------------------
# Optimizing region  63 n_sources =  19
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7727210655475822
# Final length =  0.6832004574191544
# time spent on source for a given region =  0.4857222222222225
# slewing time percentage =  0.2890487455803558
# optimum travel order =   [0, 16, 14, 9, 1, 8, 6, 7, 5, 4, 3, 11, 17, 10, 2, 18, 13, 15, 12]
#
#
# ---------------------------------------
# Optimizing region  64 n_sources =  13
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5740193252414638
# Final length =  0.5074662535833028
# time spent on source for a given region =  0.3770555555555557
# slewing time percentage =  0.2569839809187225
# optimum travel order =   [0, 1, 9, 8, 7, 6, 5, 4, 3, 2, 10, 11, 12]
#
#
# ---------------------------------------
# Optimizing region  65 n_sources =  16
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7075107454349876
# Final length =  0.6126353367541402
# time spent on source for a given region =  0.4313888888888891
# slewing time percentage =  0.29584719814813426
# optimum travel order =   [0, 7, 6, 4, 3, 2, 5, 1, 12, 9, 8, 10, 11, 13, 14, 15]
#
#
# ---------------------------------------
# Optimizing region  66 n_sources =  9
# Exact solution
# Initial path obstime =  0.4318513181814918
# Final path length =  0.38632034918834
# slewing time percentage =  0.2115064304764172
# ---------------------------------------
# Optimizing region  67 n_sources =  15
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6605108633287031
# Final length =  0.5570362014879944
# time spent on source for a given region =  0.41327777777777797
# slewing time percentage =  0.2580773445714996
# optimum travel order =   [0, 8, 12, 11, 10, 9, 13, 14, 7, 6, 1, 3, 2, 5, 4]
#
#
# ---------------------------------------
# Optimizing region  68 n_sources =  13
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7235789857531891
# Final length =  0.5424146348429808
# time spent on source for a given region =  0.3770555555555557
# slewing time percentage =  0.30485733360659334
# optimum travel order =   [0, 12, 10, 9, 11, 7, 8, 4, 3, 1, 2, 5, 6]
#
#
# ---------------------------------------
# Optimizing region  69 n_sources =  6
# Exact solution
# Initial path obstime =  0.3208580924887272
# Final path length =  0.31624980707689687
# slewing time percentage =  0.20860733452741
# ---------------------------------------
# Optimizing region  70 n_sources =  14
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5988082066172993
# Final length =  0.527505625238355
# time spent on source for a given region =  0.39516666666666683
# slewing time percentage =  0.25087686697538136
# optimum travel order =   [0, 6, 5, 4, 3, 7, 1, 2, 8, 12, 11, 9, 10, 13]
#
#
# ---------------------------------------
# Optimizing region  71 n_sources =  18
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7937953497773513
# Final length =  0.6512220408451697
# time spent on source for a given region =  0.46761111111111137
# slewing time percentage =  0.2819482729665663
# optimum travel order =   [0, 13, 17, 11, 10, 9, 8, 3, 2, 4, 14, 15, 16, 1, 12, 7, 6, 5]
#
#
# ---------------------------------------
# Optimizing region  72 n_sources =  16
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6448058238082446
# Final length =  0.5764655364916251
# time spent on source for a given region =  0.4313888888888891
# slewing time percentage =  0.2516657777768883
# optimum travel order =   [0, 14, 12, 15, 13, 1, 11, 3, 10, 2, 4, 5, 6, 8, 7, 9]
#
#
# ---------------------------------------
# Optimizing region  73 n_sources =  14
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5992808260146463
# Final length =  0.5157323046945355
# time spent on source for a given region =  0.39516666666666683
# slewing time percentage =  0.23377561756438506
# optimum travel order =   [0, 10, 12, 11, 13, 9, 8, 1, 2, 7, 6, 5, 4, 3]
#
#
# ---------------------------------------
# Optimizing region  74 n_sources =  20
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.81302637819164
# Final length =  0.7088419525332417
# time spent on source for a given region =  0.5038333333333336
# slewing time percentage =  0.2892162610681456
# optimum travel order =   [0, 8, 9, 13, 12, 14, 5, 6, 4, 18, 10, 16, 1, 17, 15, 11, 19, 7, 3, 2]
#
#
# ---------------------------------------
# Optimizing region  75 n_sources =  5
# Exact solution
# Initial path obstime =  0.29260568105215334
# Final path length =  0.27886498758662404
# slewing time percentage =  0.1674585301084148
# ---------------------------------------
# Optimizing region  76 n_sources =  11
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.4609100896659388
# Final length =  0.43182272993901183
# time spent on source for a given region =  0.34083333333333343
# slewing time percentage =  0.21071006757455593
# optimum travel order =   [0, 7, 10, 9, 8, 1, 2, 6, 5, 4, 3]
#
#
# ---------------------------------------
# Optimizing region  77 n_sources =  16
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6839066422574298
# Final length =  0.5729920935071267
# time spent on source for a given region =  0.4313888888888891
# slewing time percentage =  0.24712942154493506
# optimum travel order =   [0, 14, 15, 13, 12, 4, 3, 2, 5, 10, 11, 9, 6, 7, 8, 1]
#
#
# ---------------------------------------
# Optimizing region  79 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5371049384495468
# Final length =  0.4637647063200685
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.22602035137033893
# optimum travel order =   [0, 9, 1, 8, 10, 11, 7, 3, 2, 6, 5, 4]
#
#
# ---------------------------------------
# Optimizing region  80 n_sources =  11
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5018571123124858
# Final length =  0.4297664329896005
# time spent on source for a given region =  0.34083333333333343
# slewing time percentage =  0.20693356397710816
# optimum travel order =   [0, 4, 5, 6, 7, 10, 8, 9, 3, 2, 1]
#
#
# ---------------------------------------
# Optimizing region  81 n_sources =  15
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5801591564534601
# Final length =  0.5458724729086182
# time spent on source for a given region =  0.41327777777777797
# slewing time percentage =  0.24290416115750396
# optimum travel order =   [0, 13, 12, 11, 9, 10, 3, 5, 6, 7, 8, 4, 2, 1, 14]
#
#
# ---------------------------------------
# Optimizing region  82 n_sources =  17
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7019912673284612
# Final length =  0.620334582896314
# time spent on source for a given region =  0.44950000000000023
# slewing time percentage =  0.275391035106724
# optimum travel order =   [0, 9, 5, 15, 16, 2, 3, 4, 14, 13, 10, 7, 6, 8, 11, 12, 1]
#
#
# ---------------------------------------
# Optimizing region  83 n_sources =  20
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.8629163491063139
# Final length =  0.7172197223332759
# time spent on source for a given region =  0.5038333333333336
# slewing time percentage =  0.29751885280810286
# optimum travel order =   [0, 4, 2, 3, 18, 8, 6, 16, 17, 1, 19, 5, 10, 13, 14, 15, 11, 12, 9, 7]
#
#
# ---------------------------------------
# Optimizing region  84 n_sources =  6
# Exact solution
# Initial path obstime =  0.3222577936367834
# Final path length =  0.2984999744245975
# slewing time percentage =  0.16154841131820905
# ---------------------------------------
# Optimizing region  85 n_sources =  15
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6022087584305993
# Final length =  0.55295205185055
# time spent on source for a given region =  0.41327777777777797
# slewing time percentage =  0.25259744240993015
# optimum travel order =   [0, 13, 14, 7, 12, 1, 3, 2, 5, 6, 4, 11, 10, 9, 8]
#
#
# ---------------------------------------
# Optimizing region  86 n_sources =  14
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6220011459355987
# Final length =  0.5365915446934721
# time spent on source for a given region =  0.39516666666666683
# slewing time percentage =  0.2635615104736588
# optimum travel order =   [0, 8, 9, 13, 12, 10, 11, 1, 6, 7, 5, 3, 2, 4]
#
#
# ---------------------------------------
# Optimizing region  87 n_sources =  17
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7428274663250072
# Final length =  0.6243186263018856
# time spent on source for a given region =  0.44950000000000023
# slewing time percentage =  0.2800150739333426
# optimum travel order =   [0, 3, 6, 5, 4, 16, 11, 12, 14, 13, 15, 9, 2, 7, 10, 1, 8]
#
#
# ---------------------------------------
# Optimizing region  88 n_sources =  19
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7669604758331623
# Final length =  0.6892493162793052
# time spent on source for a given region =  0.4857222222222225
# slewing time percentage =  0.29528806086563775
# optimum travel order =   [0, 10, 18, 12, 13, 16, 5, 7, 6, 8, 9, 1, 11, 4, 14, 17, 3, 2, 15]
#
#
# ---------------------------------------
# Optimizing region  89 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5264480644584654
# Final length =  0.46767817215710084
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.2324969053208898
# optimum travel order =   [0, 7, 8, 9, 5, 6, 10, 11, 4, 3, 1, 2]
#
#
# ---------------------------------------
# Optimizing region  90 n_sources =  17
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6496571477760473
# Final length =  0.5897539992688401
# time spent on source for a given region =  0.44950000000000023
# slewing time percentage =  0.2378178010538677
# optimum travel order =   [0, 2, 4, 3, 6, 5, 9, 8, 11, 12, 10, 15, 14, 13, 1, 7, 16]
#
#
# ---------------------------------------
# Optimizing region  91 n_sources =  15
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6143502170620088
# Final length =  0.5496836486779761
# time spent on source for a given region =  0.41327777777777797
# slewing time percentage =  0.24815340828904572
# optimum travel order =   [0, 2, 11, 9, 10, 5, 4, 3, 1, 12, 14, 13, 7, 8, 6]
#
#
# ---------------------------------------
# Optimizing region  92 n_sources =  4
# Exact solution
# Initial path obstime =  0.2681297472626909
# Final path length =  0.2533236299967845
# slewing time percentage =  0.15501149435497746
# ---------------------------------------
# Optimizing region  93 n_sources =  15
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6322845751985913
# Final length =  0.5358866299681493
# time spent on source for a given region =  0.41327777777777797
# slewing time percentage =  0.2287962515460754
# optimum travel order =   [0, 4, 3, 5, 6, 7, 8, 1, 13, 10, 2, 14, 9, 11, 12]
#
#
# ---------------------------------------
# Optimizing region  94 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5146385193669971
# Final length =  0.45153571150269123
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.20505856945424528
# optimum travel order =   [0, 1, 2, 3, 6, 5, 4, 10, 7, 9, 8, 11]
#
#
# ---------------------------------------
# Optimizing region  95 n_sources =  21
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.8016157652113218
# Final length =  0.7146592330780752
# time spent on source for a given region =  0.5219444444444447
# slewing time percentage =  0.2696596919396084
# optimum travel order =   [0, 1, 12, 13, 14, 15, 10, 2, 3, 5, 4, 8, 18, 6, 17, 19, 16, 7, 9, 11, 20]
#
#
# ---------------------------------------
# Optimizing region  96 n_sources =  18
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.8580660839722203
# Final length =  0.7776739989998109
# time spent on source for a given region =  0.6092222222222222
# slewing time percentage =  0.21660975806602692
# optimum travel order =   [0, 6, 8, 10, 11, 16, 15, 17, 4, 2, 3, 14, 13, 12, 1, 7, 5, 9]
#
#
# ---------------------------------------
# Optimizing region  97 n_sources =  10
# Exact solution
# Initial path obstime =  0.4820780472659312
# Final path length =  0.4078458157072795
# slewing time percentage =  0.20871513254938578
# ---------------------------------------
# Optimizing region  98 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5321853546852804
# Final length =  0.4554506127889564
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.21189162037472148
# optimum travel order =   [0, 1, 4, 5, 6, 3, 2, 7, 8, 9, 10, 11]
#
#
# ---------------------------------------
# Optimizing region  99 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5220372379756029
# Final length =  0.4598288710508065
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.21939559031128172
# optimum travel order =   [0, 1, 3, 2, 8, 4, 5, 6, 7, 9, 10, 11]
#
#
# ---------------------------------------
# Optimizing region  101 n_sources =  20
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7806959933546338
# Final length =  0.6811062661239511
# time spent on source for a given region =  0.5038333333333336
# slewing time percentage =  0.26027206268332365
# optimum travel order =   [0, 18, 1, 8, 5, 9, 13, 16, 19, 12, 11, 10, 6, 7, 17, 4, 2, 15, 14, 3]
#
#
# ---------------------------------------
# Optimizing region  102 n_sources =  17
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.664987256018172
# Final length =  0.5963884436216382
# time spent on source for a given region =  0.44950000000000023
# slewing time percentage =  0.24629659610712915
# optimum travel order =   [0, 6, 1, 8, 13, 15, 12, 11, 10, 14, 9, 7, 4, 16, 2, 3, 5]
#
#
# ---------------------------------------
# Optimizing region  103 n_sources =  11
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.515877870266749
# Final length =  0.4354142693012868
# time spent on source for a given region =  0.34083333333333343
# slewing time percentage =  0.21722057046896567
# optimum travel order =   [0, 1, 6, 8, 9, 10, 7, 3, 2, 4, 5]
#
#
# ---------------------------------------
# Optimizing region  104 n_sources =  18
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.6650059760447782
# Final length =  0.6256808243223126
# time spent on source for a given region =  0.46761111111111137
# slewing time percentage =  0.25263633959440857
# optimum travel order =   [0, 10, 1, 6, 5, 8, 7, 2, 3, 17, 9, 15, 13, 11, 12, 16, 14, 4]
#
#
# ---------------------------------------
# Optimizing region  105 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5099702849727947
# Final length =  0.45108893346489864
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.20427122499475878
# optimum travel order =   [0, 4, 3, 2, 1, 7, 6, 5, 8, 10, 9, 11]
#
#
# ---------------------------------------
# Optimizing region  106 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5107512308776982
# Final length =  0.46484256779818267
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.227815029624643
# optimum travel order =   [0, 1, 11, 10, 4, 3, 2, 9, 8, 7, 6, 5]
#
#
# ---------------------------------------
# Optimizing region  107 n_sources =  13
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5370800667400353
# Final length =  0.48047999700244404
# time spent on source for a given region =  0.3770555555555557
# slewing time percentage =  0.21525233535655858
# optimum travel order =   [0, 10, 8, 9, 11, 12, 7, 6, 2, 1, 3, 4, 5]
#
#
# ---------------------------------------
# Optimizing region  108 n_sources =  6
# Exact solution
# Initial path obstime =  0.31157994589337434
# Final path length =  0.292742417151743
# slewing time percentage =  0.14505803356796662
# ---------------------------------------
# Optimizing region  109 n_sources =  11
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5006229374475311
# Final length =  0.4195524926467762
# time spent on source for a given region =  0.34083333333333343
# slewing time percentage =  0.18762648463089193
# optimum travel order =   [0, 1, 2, 3, 4, 5, 6, 9, 10, 8, 7]
#
#
# ---------------------------------------
# Optimizing region  110 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.49613145300755157
# Final length =  0.4422651224473171
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.1883953171387548
# optimum travel order =   [0, 7, 8, 1, 9, 10, 11, 4, 3, 2, 5, 6]
#
#
# ---------------------------------------
# Optimizing region  111 n_sources =  23
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.7998156830074592
# Final length =  0.7421500426930159
# time spent on source for a given region =  0.5581666666666668
# slewing time percentage =  0.24790590236811755
# optimum travel order =   [0, 8, 7, 11, 10, 15, 21, 20, 6, 18, 19, 17, 5, 16, 4, 22, 3, 2, 14, 12, 9, 13, 1]
#
#
# ---------------------------------------
# Optimizing region  112 n_sources =  14
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5308632200118346
# Final length =  0.4911440536317073
# time spent on source for a given region =  0.39516666666666683
# slewing time percentage =  0.1954159604607791
# optimum travel order =   [0, 8, 9, 10, 11, 13, 2, 12, 1, 3, 5, 6, 4, 7]
#
#
# ---------------------------------------
# Optimizing region  113 n_sources =  10
# Exact solution
# Initial path obstime =  0.4695164659382822
# Final path length =  0.40199655909852616
# slewing time percentage =  0.19720153091378664
# ---------------------------------------
# Optimizing region  114 n_sources =  13
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5299332546665543
# Final length =  0.4844540943983109
# time spent on source for a given region =  0.3770555555555557
# slewing time percentage =  0.22168981557714676
# optimum travel order =   [0, 1, 11, 2, 3, 5, 4, 6, 7, 8, 10, 9, 12]
#
#
# ---------------------------------------
# Optimizing region  115 n_sources =  5
# Exact solution
# Initial path obstime =  0.28749168838369155
# Final path length =  0.27230345320552196
# slewing time percentage =  0.14739727339616934
# ---------------------------------------
# Optimizing region  116 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.49037956954537965
# Final length =  0.4483033673505412
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.19932690542612935
# optimum travel order =   [0, 1, 11, 10, 9, 3, 2, 4, 5, 6, 7, 8]
#
#
# ---------------------------------------
# Optimizing region  117 n_sources =  9
# Exact solution
# Initial path obstime =  0.43252606393926385
# Final path length =  0.38379130246793114
# slewing time percentage =  0.2063105412959068
# ---------------------------------------
# Optimizing region  118 n_sources =  11
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.4583943826796135
# Final length =  0.4229429427330451
# time spent on source for a given region =  0.34083333333333343
# slewing time percentage =  0.19413873859467132
# optimum travel order =   [0, 1, 2, 3, 4, 7, 5, 6, 8, 9, 10]
#
#
# ---------------------------------------
# Optimizing region  119 n_sources =  12
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5165628779182718
# Final length =  0.4530220988367084
# time spent on source for a given region =  0.35894444444444457
# slewing time percentage =  0.2076668105901255
# optimum travel order =   [0, 2, 3, 4, 5, 11, 10, 9, 8, 6, 7, 1]
#
#
# ---------------------------------------
# Optimizing region  121 n_sources =  11
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.4424535542675585
# Final length =  0.40897683833291865
# time spent on source for a given region =  0.34083333333333343
# slewing time percentage =  0.16661947233333171
# optimum travel order =   [0, 1, 10, 9, 8, 2, 7, 4, 3, 5, 6]
#
#
# ---------------------------------------
# Optimizing region  122 n_sources =  10
# Exact solution
# Initial path obstime =  0.4152985226837842
# Final path length =  0.3919990664207944
# slewing time percentage =  0.17672706425327642
# ---------------------------------------
# Optimizing region  123 n_sources =  4
# Exact solution
# Initial path obstime =  0.24542919780337513
# Final path length =  0.24542919780337513
# slewing time percentage =  0.12783174344624842
# ---------------------------------------
# Optimizing region  124 n_sources =  9
# Exact solution
# Initial path obstime =  0.3828782926070833
# Final path length =  0.36507359776988046
# slewing time percentage =  0.16561725369381838
# ---------------------------------------
# Optimizing region  125 n_sources =  7
# Exact solution
# Initial path obstime =  0.35175733709737855
# Final path length =  0.3131872138946683
# slewing time percentage =  0.1430400827948425
# ---------------------------------------
# Optimizing region  126 n_sources =  13
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5254465820875112
# Final length =  0.4802105045594356
# time spent on source for a given region =  0.3770555555555557
# slewing time percentage =  0.2148119377324292
# optimum travel order =   [0, 6, 2, 3, 4, 5, 12, 11, 1, 7, 10, 8, 9]
#
#
# ---------------------------------------
# Optimizing region  127 n_sources =  13
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5018459534410233
# Final length =  0.4720762622468069
# time spent on source for a given region =  0.3770555555555557
# slewing time percentage =  0.2012825348154728
# optimum travel order =   [0, 6, 5, 4, 7, 10, 12, 11, 9, 8, 1, 2, 3]
#
#
# ---------------------------------------
# Optimizing region  128 n_sources =  6
# Exact solution
# Initial path obstime =  0.3106559617942146
# Final path length =  0.29033952929959383
# slewing time percentage =  0.13798242222979354
# ---------------------------------------
# Optimizing region  129 n_sources =  6
# Exact solution
# Initial path obstime =  0.30083767425323593
# Final path length =  0.2877832321320426
# slewing time percentage =  0.13032536356064114
# ---------------------------------------
# Optimizing region  130 n_sources =  6
# Exact solution
# Initial path obstime =  0.3070518712736856
# Final path length =  0.2999027165518031
# slewing time percentage =  0.16547012092654215
# ---------------------------------------
# Optimizing region  131 n_sources =  8
# Exact solution
# Initial path obstime =  0.3728888056201427
# Final path length =  0.341527632842169
# slewing time percentage =  0.16112205148448133
# ---------------------------------------
# Optimizing region  132 n_sources =  7
# Exact solution
# Initial path obstime =  0.33841866995333136
# Final path length =  0.31465646825233096
# slewing time percentage =  0.14704156447322392
# ---------------------------------------
# Optimizing region  133 n_sources =  10
# Exact solution
# Initial path obstime =  0.41426922118166676
# Final path length =  0.39170806147681203
# slewing time percentage =  0.17611544422777597
# ---------------------------------------
# Optimizing region  134 n_sources =  14
# Using tam_poblacion = 1000, prob_mutacion = 0.9 and num_generaciones = 50.
# Genetic algorithm solution
# Initial path obstime =  0.5308597806750696
# Final length =  0.4879162102743002
# time spent on source for a given region =  0.39516666666666683
# slewing time percentage =  0.19009317922741442
# optimum travel order =   [0, 6, 1, 4, 2, 12, 13, 3, 5, 10, 9, 11, 8, 7]
#
#
# ---------------------------------------
# Optimizing region  135 n_sources =  5
# Exact solution
# Initial path obstime =  0.2632109281153596
# Final path length =  0.2596442228213398
# slewing time percentage =  0.1058277201629877
# ---------------------------------------
# Optimizing region  136 n_sources =  4
# Exact solution
# Initial path obstime =  0.6498061588142203
# Final path length =  0.6498061588142203
# slewing time percentage =  0.016800810175843124
# ---------------------------------------
# Optimizing region  137 n_sources =  3
# Exact solution
# Initial path obstime =  0.4864448466168838
# Final path length =  0.4864448466168838
# slewing time percentage =  0.014961983873064558
# ---------------------------------------
# Optimizing region  138 n_sources =  4
# Exact solution
# Initial path obstime =  0.649806158814215
# Final path length =  0.649806158814215
# slewing time percentage =  0.01680081017583506
# ---------------------------------------
# Optimizing region  139 n_sources =  4
# Exact solution
# Initial path obstime =  0.649806158814215
# Final path length =  0.649806158814215
# slewing time percentage =  0.01680081017583506
# ---------------------------------------
# Optimizing region  140 n_sources =  4
# Exact solution
# Initial path obstime =  0.6498061588142203
# Final path length =  0.6498061588142203
# slewing time percentage =  0.016800810175843124
# ---------------------------------------
# Optimizing region  141 n_sources =  4
# Exact solution
# Initial path obstime =  0.6498061588142239
# Final path length =  0.6498061588142239
# slewing time percentage =  0.0168008101758485
# ---------------------------------------
# Optimizing region  142 n_sources =  4
# Exact solution
# Initial path obstime =  0.649806158814223
# Final path length =  0.649806158814223
# slewing time percentage =  0.016800810175847156
# ----------------------------------
# Total observing time  77.72580695689098
# Total program execution time is: 19.304429499308267 minutes.

# %%
last_order = []
cant=0
for k in range(143):
    if k in [23,43,78,100,120]: #para las regiones vacias
        element = [k, []]
        cant+=1
    else:
        if cant!=0:
            element = [int(regions[k-cant]['number']), regions[k-cant]['order']]
        else:
            element = [int(regions[k]['number']), regions[k]['order']]
    last_order.append(element)
last_order[:2]

# %%
#import ipynb.fs.full.region_optimizer_with_genetic as regopt #para actualizar parámetros.

t0 = time.time()
sources, regions, data = regopt.optimize_all_regions(sources, regions, last_order, n_exact=10)
tf = time.time()
time_taken = tf-t0
print('Total program execution time is:', time_taken/60, 'minutes.')

# %%
exact_total_time = 15.868352020398408
total_observing_time = 74.27159419268125
print(f"Donde, el tiempo de observación para las regiones con al menos 11 fuentes (ejecutadas con algorito genético) es de {total_observing_time-exact_total_time} \n y el tiempo de observación dedicado a las regiones con a lo más 10 fuentes (bajo la búsqueda de la solución exacta es de {exact_total_time}. \n Por consiguiente, el tiempo total de observación es de {total_observing_time}. ")
# Out:
# Donde, el tiempo de observación para las regiones con al menos 11 fuentes (ejecutadas con algorito genético) es de 58.403242172282845
#  y el tiempo de observación dedicado a las regiones con a lo más 10 fuentes (bajo la búsqueda de la solución exacta es de 15.868352020398408.
#  Por consiguiente, el tiempo total de observación es de 74.27159419268125.
